# %% [markdown]
# ## 2418 women who hold office in 2020, USA

# %% [markdown]
# ## We can read the largest words in this word cloud and realize the most occupied position by women
# ## There are three the most taken - "State Representative",  "State Senator", and "U.S. Representative"

# %%
#count - count of respondents 
temp = df.groupby('Position')['Position'].count().rename('count').reset_index()
cloud_df(temp, 'Position', 'What is the position of Women Elected Officials in 2020?')
